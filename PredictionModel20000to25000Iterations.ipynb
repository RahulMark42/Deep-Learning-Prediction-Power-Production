# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split

# %%
PATH = "C:/Users/rahul/Desktop/Final Year Project/Datasets"
T1 = PATH + "/Inputs & output.xlsx"

# %%
data = pd.read_excel(T1, header = 1)

# %%
data = data.drop("Number", axis=1)
data = data.drop("Biomass type", axis=1)

# %%
data
# Out:
#          M    VM    FC     A        C        O       H       N       S  \
# 0     52.6  76.6  19.2   4.2  50.9656  38.5116  5.8438  0.4790  0.0000
# 1     52.6  76.6  19.2   4.2  50.9656  38.5116  5.8438  0.4790  0.0000
# 2     52.6  76.6  19.2   4.2  50.9656  38.5116  5.8438  0.4790  0.0000
# 3     52.6  76.6  19.2   4.2  50.9656  38.5116  5.8438  0.4790  0.0000
# 4     52.6  76.6  19.2   4.2  50.9656  38.5116  5.8438  0.4790  0.0000
# ...    ...   ...   ...   ...      ...      ...     ...     ...     ...
# 1027  38.1  66.0  13.6  20.4  41.5512  32.1584  4.7760  0.8756  0.2388
# 1028  38.1  66.0  13.6  20.4  41.5512  32.1584  4.7760  0.8756  0.2388
# 1029  38.1  66.0  13.6  20.4  41.5512  32.1584  4.7760  0.8756  0.2388
# 1030  38.1  66.0  13.6  20.4  41.5512  32.1584  4.7760  0.8756  0.2388
# 1031  38.1  66.0  13.6  20.4  41.5512  32.1584  4.7760  0.8756  0.2388
#
#       T (˚C)  AFR (kg/kg)   Wnet (kW)
# 0        600          1.8   50.646995
# 1        600          2.0   47.490069
# 2        600          2.3   44.021257
# 3        900          1.8  103.090293
# 4        900          2.0   98.030617
# ...      ...          ...         ...
# 1027    1200          2.0   65.234100
# 1028    1200          2.3   57.348570
# 1029    1500          1.8   96.825749
# 1030    1500          2.0   92.012450
# 1031    1500          2.3   86.588055
#
# [1032 rows x 12 columns]

# %%
X = data.iloc[:, :11]
X = X.to_numpy(dtype=float)
X.shape
# Out:
# (1032, 11)

# %%
X[2]
# Out:
# array([5.26000e+01, 7.66000e+01, 1.92000e+01, 4.20000e+00, 5.09656e+01,
#        3.85116e+01, 5.84380e+00, 4.79000e-01, 0.00000e+00, 6.00000e+02,
#        2.30000e+00])

# %%
Y = data.iloc[:, 11:]
Y = Y.to_numpy(dtype=float)
Y.shape
# Out:
# (1032, 1)

# %%
Y[2]
# Out:
# array([44.0212568])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce GTX 1650 Ti'

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 1/5, random_state = 1)
X_train = (X_train - np.mean(X_train)) / np.std(X_train)
X_test = (X_test - np.mean(X_test)) / np.std(X_test)

# %%
X_test[2]
# Out:
# array([-0.34353008, -0.17485219, -0.24360851, -0.35638173, -0.20954265,
#        -0.23296478, -0.34601559, -0.36100575, -0.36506559,  4.45399026,
#        -0.35895206])

# %%
y_test[2]
# Out:
# array([240.816006])

# %%
X_train = torch.from_numpy(X_train).float().to(device)
y_train = torch.from_numpy(y_train).float().to(device)
X_test = torch.from_numpy(X_test).float().to(device)
y_test = torch.from_numpy(y_test).float().to(device)

train_ds = TensorDataset(X_train, y_train)
#test_ds = TensorDataset(X_test, y_test)
torch.manual_seed(1)
batch_size = 1
train_dl = DataLoader(train_ds, batch_size, shuffle = True)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(NeuralNetwork, self).__init__()
        self.firstlayer = nn.Linear(input_size, hidden_size)
        self.secondlayer = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = self.firstlayer(x)
        x = nn.Sigmoid()(x)
        x = self.secondlayer(x)
        return x

    def predict(self, x):
        pred = self.forward(x)
        return pred

# %%
network = NeuralNetwork(11, 40, 1).to(device)

# %%
network
# Out:
# NeuralNetwork(
#   (firstlayer): Linear(in_features=11, out_features=40, bias=True)
#   (secondlayer): Linear(in_features=40, out_features=1, bias=True)
# )

# %%
network.load_state_dict(torch.load("modelStateDict.pth"))
# Out:
# <All keys matched successfully>

# %%
num_epochs = 5000
log_epochs = 100
learning_rate = 0.0002
lossfunc = nn.MSELoss()
optimizer = optim.Adam(network.parameters(), lr=learning_rate)
loss_hist = [0] * num_epochs
accuracy_hist = [0]*num_epochs

# %%
for epochs in range(num_epochs):
    count = 0
    for x, y in train_dl:
        prediction = network.predict(x)
        loss = lossfunc(prediction, y)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        loss_hist[epochs] += loss.item()*y.size(0)
        if(torch.abs(prediction - y) <= torch.tensor(20)): count += 1
        
    loss_hist[epochs] /= len(train_dl.dataset)
    accuracy_hist[epochs] = count/len(train_dl.dataset)
    if epochs % log_epochs==0:
        print(f'Epoch {epochs} Loss 'f'{loss_hist[epochs]:.4f}')
        print(f'Epoch {epochs} Accuracy 'f'{accuracy_hist[epochs]:.4f}')
# Out:
# Epoch 0 Loss 832.0272
# Epoch 0 Accuracy 0.7503
# Epoch 100 Loss 830.0509
# Epoch 100 Accuracy 0.7503
# Epoch 200 Loss 830.9854
# Epoch 200 Accuracy 0.7455
# Epoch 300 Loss 828.2313
# Epoch 300 Accuracy 0.7479
# Epoch 400 Loss 823.0208
# Epoch 400 Accuracy 0.7455
# Epoch 500 Loss 821.9415
# Epoch 500 Accuracy 0.7552
# Epoch 600 Loss 823.0707
# Epoch 600 Accuracy 0.7479
# Epoch 700 Loss 818.4308
# Epoch 700 Accuracy 0.7503
# Epoch 800 Loss 819.9518
# Epoch 800 Accuracy 0.7552
# Epoch 900 Loss 817.5165
# Epoch 900 Accuracy 0.7503
# Epoch 1000 Loss 817.1243
# Epoch 1000 Accuracy 0.7552
# Epoch 1100 Loss 814.9080
# Epoch 1100 Accuracy 0.7527
# Epoch 1200 Loss 817.3679
# Epoch 1200 Accuracy 0.7588
# Epoch 1300 Loss 814.3303
# Epoch 1300 Accuracy 0.7588
# Epoch 1400 Loss 813.5388
# Epoch 1400 Accuracy 0.7624
# Epoch 1500 Loss 809.0733
# Epoch 1500 Accuracy 0.7552
# Epoch 1600 Loss 809.1162
# Epoch 1600 Accuracy 0.7624
# Epoch 1700 Loss 807.4766
# Epoch 1700 Accuracy 0.7636
# Epoch 1800 Loss 806.1256
# Epoch 1800 Accuracy 0.7636
# Epoch 1900 Loss 804.0056
# Epoch 1900 Accuracy 0.7648
# Epoch 2000 Loss 802.3269
# Epoch 2000 Accuracy 0.7515
# Epoch 2100 Loss 802.8505
# Epoch 2100 Accuracy 0.7612
# Epoch 2200 Loss 801.1606
# Epoch 2200 Accuracy 0.7661
# Epoch 2300 Loss 799.4737
# Epoch 2300 Accuracy 0.7709
# Epoch 2400 Loss 799.4832
# Epoch 2400 Accuracy 0.7745
# Epoch 2500 Loss 796.9741
# Epoch 2500 Accuracy 0.7576
# Epoch 2600 Loss 797.3279
# Epoch 2600 Accuracy 0.7673
# Epoch 2700 Loss 793.3006
# Epoch 2700 Accuracy 0.7648
# Epoch 2800 Loss 794.0790
# Epoch 2800 Accuracy 0.7673
# Epoch 2900 Loss 791.9429
# Epoch 2900 Accuracy 0.7685
# Epoch 3000 Loss 790.6776
# Epoch 3000 Accuracy 0.7648
# Epoch 3100 Loss 788.9624
# Epoch 3100 Accuracy 0.7685
# Epoch 3200 Loss 788.2021
# Epoch 3200 Accuracy 0.7709
# Epoch 3300 Loss 788.2156
# Epoch 3300 Accuracy 0.7709
# Epoch 3400 Loss 788.3747
# Epoch 3400 Accuracy 0.7721
# Epoch 3500 Loss 786.0439
# Epoch 3500 Accuracy 0.7661
# Epoch 3600 Loss 786.2446
# Epoch 3600 Accuracy 0.7733
# Epoch 3700 Loss 784.4614
# Epoch 3700 Accuracy 0.7685
# Epoch 3800 Loss 781.0771
# Epoch 3800 Accuracy 0.7745
# Epoch 3900 Loss 778.1130
# Epoch 3900 Accuracy 0.7709
# Epoch 4000 Loss 781.1042
# Epoch 4000 Accuracy 0.7685
# Epoch 4100 Loss 779.0415
# Epoch 4100 Accuracy 0.7697
# Epoch 4200 Loss 778.6030
# Epoch 4200 Accuracy 0.7745
# Epoch 4300 Loss 771.7478
# Epoch 4300 Accuracy 0.7758
# Epoch 4400 Loss 776.1888
# Epoch 4400 Accuracy 0.7770
# Epoch 4500 Loss 774.4785
# Epoch 4500 Accuracy 0.7673
# Epoch 4600 Loss 773.8885
# Epoch 4600 Accuracy 0.7673
# Epoch 4700 Loss 770.6471
# Epoch 4700 Accuracy 0.7709
# Epoch 4800 Loss 773.4132
# Epoch 4800 Accuracy 0.7721
# Epoch 4900 Loss 771.7601
# Epoch 4900 Accuracy 0.7709

# %%
import pickle
pickle_in1 = open('loss.pickle', 'rb')
loss_hist_prev = pickle.load(pickle_in1)
pickle_in2 = open('accuracy.pickle', 'rb')
accuracy_hist_prev = pickle.load(pickle_in2)

# %%
loss_hist_new = []
accuracy_hist_new = []
loss_hist_new = loss_hist_prev + loss_hist
accuracy_hist_new = accuracy_hist_prev + accuracy_hist

# %%
len(loss_hist_new)
# Out:
# 25000

# %%
plt.plot(loss_hist_new)

# %%
plt.plot(accuracy_hist_new)

# %%
pickle.dump(loss_hist_new, open('loss.pickle', 'wb'))
pickle.dump(accuracy_hist_new, open('accuracy.pickle', 'wb'))

# %%
torch.save(network.state_dict(), "modelStateDict.pth")
